# %%
import pandas as pd   # Import the pandas library for data manipulation
import numpy as np
import matplotlib.pyplot as plt    # Import the matplotlib library for plotting
import seaborn as sns    # Import the seaborn library for advanced data visualization

# %%
data = pd.read_csv('train-chennai-sale.csv')
data.head(10)
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  P09411  Anna Nagar      1986  19-12-2006        2.0         1.0       5
# 1  P05346   Velachery      1855  13-03-2010        3.0         2.0       5
# 2  P00219    Chrompet      1220  11-09-2014        2.0         1.0       4
# 3  P09105    Chrompet      1167  05-04-2007        1.0         1.0       3
# 4  P09679   Velachery      1847  13-03-2006        3.0         2.0       5
# 5  P03377    Chrompet       771  06-04-2011        1.0         1.0       2
# 6  P09623   Velachery      1635  22-06-2006        2.0         1.0       4
# 7  P07121    Chrompet      1054  16-02-2009        1.0         1.0       3
# 8  P05512    Chrompet      1196  11-02-2010        1.0         1.0       3
# 9  P04085   Velachery      1865  11-11-2010        3.0         2.0       5
#
#    SALE_COND PARK_FACIL  DATE_BUILD  ... QS_ROOMS QS_BATHROOM QS_BEDROOM  \
# ...

# %%
data.shape
# Out:
# (7109, 24)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRT_ID         7109 non-null   object
#  1   AREA           7109 non-null   object
#  2   INT_SQFT       7109 non-null   int64
#  3   DATE_SALE      7109 non-null   object
#  4   N_BEDROOM      7108 non-null   float64
#  5   N_BATHROOM     7104 non-null   float64
#  6   N_ROOM         7109 non-null   int64
#  7   SALE_COND      7109 non-null   object
#  8   PARK_FACIL     7109 non-null   object
#  9   DATE_BUILD     7109 non-null   object
#  10  BUILDTYPE      7109 non-null   object
#  11  UTILITY_AVAIL  7109 non-null   object
#  12  STREET         7109 non-null   object
#  13  MZZONE         7109 non-null   object
#  14  QS_ROOMS       7109 non-null   float64
#  15  QS_BATHROOM    7109 non-null   float64
#  16  QS_BEDROOM     7109 non-null   float64
# ...

# %%
data.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DATE_SALE', 'N_BEDROOM', 'N_BATHROOM',
#        'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD', 'BUILDTYPE',
#        'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS', 'QS_BATHROOM',
#        'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS', 'SALES_PRICE',
#        'INF_PRICE', '1+0.04', 'POWER(Z,Y)'],
#       dtype='object')

# %%
data.describe()
# Out:
#           INT_SQFT    N_BEDROOM   N_BATHROOM       N_ROOM     QS_ROOMS  \
# count  7109.000000  7108.000000  7104.000000  7109.000000  7109.000000
# mean   1382.073006     1.637029     1.213260     3.688704     3.517471
# std     457.410902     0.802902     0.409639     1.019099     0.891972
# min     500.000000     1.000000     1.000000     2.000000     2.000000
# 25%     993.000000     1.000000     1.000000     3.000000     2.700000
# 50%    1373.000000     1.000000     1.000000     4.000000     3.500000
# 75%    1744.000000     2.000000     1.000000     4.000000     4.300000
# max    2500.000000     4.000000     2.000000     6.000000     5.000000
#
#        QS_BATHROOM   QS_BEDROOM   QS_OVERALL        REG_FEE         COMMIS  \
# count  7109.000000  7109.000000  7061.000000    7109.000000    7109.000000
# mean      3.507244     3.485300     3.503254  376938.330708  141005.726544
# std       0.897834     0.887266     0.527223  143070.662010   78768.093718
# ...

# %%
data.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DATE_SALE         0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# DATE_BUILD        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# REG_FEE           0
# COMMIS            0
# SALES_PRICE       0
# INF_PRICE         0
# 1+0.04            0
# POWER(Z,Y)        0
# dtype: int64

# %%
null_rows = data[data.isna().any(axis=1)]
print(null_rows)
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 10    P06328   Velachery      1868  12-09-2009        3.0         2.0       5
# 35    P05304  Anna Nagar      1589  22-03-2010        1.0         NaN       4
# 68    P00089     T Nagar      1942  20-12-2014        2.0         1.0       5
# 83    P06964   Velachery      1824  03-04-2009        3.0         2.0       5
# 97    P08752       Adyar       738  02-09-2007        1.0         1.0       2
# 131   P04590       Adyar      1249  04-08-2010        2.0         2.0       4
# 152   P02964    KK Nagar      2078  22-06-2011        3.0         2.0       5
# 158   P01156  Anna Nagar      1585  25-11-2012        1.0         1.0       4
# 242   P08647  Anna Nagar      1898  09-10-2007        2.0         1.0       5
# 294   P02698  Anna Nagar      1510  15-08-2011        1.0         1.0       4
# 363   P01445    Chrompet       944  02-05-2012        1.0         1.0       3
# ...

# %%
data = data.fillna(0)
data.isnull().sum()
# Out:
# PRT_ID           0
# AREA             0
# INT_SQFT         0
# DATE_SALE        0
# N_BEDROOM        0
# N_BATHROOM       0
# N_ROOM           0
# SALE_COND        0
# PARK_FACIL       0
# DATE_BUILD       0
# BUILDTYPE        0
# UTILITY_AVAIL    0
# STREET           0
# MZZONE           0
# QS_ROOMS         0
# QS_BATHROOM      0
# QS_BEDROOM       0
# QS_OVERALL       0
# REG_FEE          0
# COMMIS           0
# SALES_PRICE      0
# INF_PRICE        0
# 1+0.04           0
# POWER(Z,Y)       0
# dtype: int64

# %%
data.shape
# Out:
# (7109, 24)

# %%
data.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DATE_SALE         object
# N_BEDROOM        float64
# N_BATHROOM       float64
# N_ROOM             int64
# SALE_COND         object
# PARK_FACIL        object
# DATE_BUILD        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL       float64
# REG_FEE            int64
# COMMIS             int64
# SALES_PRICE        int64
# INF_PRICE        float64
# 1+0.04           float64
# POWER(Z,Y)       float64
# dtype: object

# %%
data1 = data.duplicated().sum()   # To calculate the number of duplicate rows in the DataFrame and store it in the variable 'data1'
data1
# Out:
# 0

# %%
data['DATE_SALE'] = pd.to_datetime(data['DATE_SALE'])
data['DATE_BUILD'] = pd.to_datetime(data['DATE_BUILD'])
# Calculate the age of the house at the time of sale
data['AGE_AT_SALE'] = (data['DATE_SALE'] - data['DATE_BUILD']).dt.days // 365  # // give the remainder
data.head(10)
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_12876\3089359867.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['DATE_SALE'] = pd.to_datetime(data['DATE_SALE'])
# C:\Users\deepa\AppData\Local\Temp\ipykernel_12876\3089359867.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['DATE_BUILD'] = pd.to_datetime(data['DATE_BUILD'])
#    PRT_ID        AREA  INT_SQFT  DATE_SALE  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  P09411  Anna Nagar      1986 2006-12-19        2.0         1.0       5
# 1  P05346   Velachery      1855 2010-03-13        3.0         2.0       5
# 2  P00219    Chrompet      1220 2014-09-11        2.0         1.0       4
# 3  P09105    Chrompet      1167 2007-04-05        1.0         1.0       3
# ...

# %%
data['Total_price'] = data['REG_FEE']+data['COMMIS']+data['SALES_PRICE']
data.head(10)
# Out:
#    PRT_ID        AREA  INT_SQFT  DATE_SALE  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  P09411  Anna Nagar      1986 2006-12-19        2.0         1.0       5
# 1  P05346   Velachery      1855 2010-03-13        3.0         2.0       5
# 2  P00219    Chrompet      1220 2014-09-11        2.0         1.0       4
# 3  P09105    Chrompet      1167 2007-04-05        1.0         1.0       3
# 4  P09679   Velachery      1847 2006-03-13        3.0         2.0       5
# 5  P03377    Chrompet       771 2011-04-06        1.0         1.0       2
# 6  P09623   Velachery      1635 2006-06-22        2.0         1.0       4
# 7  P07121    Chrompet      1054 2009-02-16        1.0         1.0       3
# 8  P05512    Chrompet      1196 2010-02-11        1.0         1.0       3
# 9  P04085   Velachery      1865 2010-11-11        3.0         2.0       5
#
#    SALE_COND PARK_FACIL DATE_BUILD  ... QS_BEDROOM QS_OVERALL REG_FEE  COMMIS  \
# ...

# %%
data2 = data.drop(['DATE_BUILD','DATE_SALE','PRT_ID','1+0.04','POWER(Z,Y)','INF_PRICE','REG_FEE','COMMIS','SALES_PRICE','QS_ROOMS', 'QS_BATHROOM', 'QS_BEDROOM','UTILITY_AVAIL', 'QS_OVERALL','SALE_COND'],axis=1)
data2.head(10)
# Out:
#          AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM PARK_FACIL   BUILDTYPE  \
# 0  Anna Nagar      1986        2.0         1.0       5         No  Commercial
# 1   Velachery      1855        3.0         2.0       5         No      Others
# 2    Chrompet      1220        2.0         1.0       4         No  Commercial
# 3    Chrompet      1167        1.0         1.0       3         No      Others
# 4   Velachery      1847        3.0         2.0       5         No  Commercial
# 5    Chrompet       771        1.0         1.0       2         No      Others
# 6   Velachery      1635        2.0         1.0       4         No      Others
# 7    Chrompet      1054        1.0         1.0       3         No      Others
# 8    Chrompet      1196        1.0         1.0       3         No      Others
# 9   Velachery      1865        3.0         2.0       5         No  Commercial
#
#       STREET MZZONE  AGE_AT_SALE  Total_price
# 0     Gravel     RH           11     22781941
# ...

# %%
data2.columns
# Out:
# Index(['AREA', 'INT_SQFT', 'N_BEDROOM', 'N_BATHROOM', 'N_ROOM', 'PARK_FACIL',
#        'BUILDTYPE', 'STREET', 'MZZONE', 'AGE_AT_SALE', 'Total_price'],
#       dtype='object')

# %% [markdown]
# # Data Visualizations

# %% [markdown]
# # Pie Chart

# %%
data_geograph = data['AREA'].value_counts()
data_geograph
# Out:
# AREA
# Chrompet      1702
# Karapakkam    1366
# KK Nagar       997
# Velachery      981
# Anna Nagar     788
# Adyar          774
# T Nagar        501
# Name: count, dtype: int64

# %%
keys = data_geograph.keys().to_list()

# %%
count = data_geograph.to_list()

# %%
plt.pie(x=count,labels=keys,autopct='%1.1f%%')
plt.title('Region wise distribution')
plt.show()

# %% [markdown]
# # Line Plot

# %%
plt.plot(data['SALES_PRICE'],data['AGE_AT_SALE'],color='pink',marker='^')   
plt.xlabel('age at Sale')
plt.ylabel('Sales price')
plt.title('Impact of Property Age on Sales Price')
plt.show()
plt.plot(data['SALES_PRICE'],data['INT_SQFT'],color='g',marker='*')
plt.xlabel('Sales Price')
plt.ylabel('Square feet')
plt.title('Square Feet vs. Sales Price')
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.hist(data['COMMIS'],color='blue')
plt.xlabel('Commision')
plt.ylabel('frequency')
plt.title('Commission Distribution')
plt.show()

# %% [markdown]
# The distribution is right-skewed, meaning that most of the commission values are concentrated at the lower end, with fewer occurrences of higher commission values.
# The highest frequency occurs within a commission range of approximately 50,000 to 150,000.
# As the commission amount increases, the number of occurrences decreases sharply.
# Very few data points exist for commissions above 300,000.

# %%
plt.hist(data['AGE_AT_SALE'],color='green')
plt.xlabel('Age o the property at sale')
plt.ylabel('frequency')
plt.title('Property Age Distribution')
plt.show()

# %% [markdown]
# # Bar plot

# %%
bedroom_counts = data['N_BEDROOM'].value_counts()  # Count the number of occurrences for each number of bedrooms
plt.bar(bedroom_counts.index, bedroom_counts.values, color='blue')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Count of Properties')
plt.title('Distribution of Properties by Number of Bedrooms')
plt.show()

# %% [markdown]
# # Scatter plot

# %%
plt.scatter(data['SALES_PRICE'],data['INT_SQFT'])
plt.xlabel('sales price')
plt.ylabel('Square feet')
plt.title('Scatter Plot of price and squarefeet')
plt.show()
plt.scatter(data['AGE_AT_SALE'], data['QS_OVERALL'],color='gold')
plt.xlabel('Age')
plt.ylabel('Overall Quality')
plt.title('Scatter Plot of age and quality')
plt.show()

# %% [markdown]
# # Distribution Plot

# %%
sns.distplot(data['SALES_PRICE'],color='olive')
plt.xlabel('Sales price')
plt.ylabel('Density')
plt.title('Distribution of property by sales price ')
plt.show()
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_12876\810859511.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['SALES_PRICE'],color='olive')
# C:\Users\deepa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\deepa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
data2.head(5)
# Out:
#          AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM PARK_FACIL   BUILDTYPE  \
# 0  Anna Nagar      1986        2.0         1.0       5         No  Commercial
# 1   Velachery      1855        3.0         2.0       5         No      Others
# 2    Chrompet      1220        2.0         1.0       4         No  Commercial
# 3    Chrompet      1167        1.0         1.0       3         No      Others
# 4   Velachery      1847        3.0         2.0       5         No  Commercial
#
#       STREET MZZONE  AGE_AT_SALE  Total_price
# 0     Gravel     RH           11     22781941
# 1      Paved      I           22     10063653
# 2  No Access     RH            5     13002093
# 3  No Access     RL           28      8785897
# 4     Gravel     RM           10     17640263

# %% [markdown]
# # Converting text columns to numeric

# %%
from sklearn.preprocessing import LabelEncoder
data3 = data2.copy()
data3 = data3.fillna(0)
ar = LabelEncoder()
pf = LabelEncoder()
bt = LabelEncoder()
st = LabelEncoder()
mz = LabelEncoder()

data3['AREA'] = ar.fit_transform(data3.AREA)
data3['PARK_FACIL'] = pf.fit_transform(data3.PARK_FACIL)
data3['BUILDTYPE'] = bt.fit_transform(data3.BUILDTYPE)
data3['STREET'] = st.fit_transform(data3.STREET)
data3['MZZONE'] = mz.fit_transform(data3.MZZONE)
data3.head(5)
# Out:
#    AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM  PARK_FACIL  BUILDTYPE  \
# 0     1      1986        2.0         1.0       5           0          0
# 1     6      1855        3.0         2.0       5           0          2
# 2     2      1220        2.0         1.0       4           0          0
# 3     2      1167        1.0         1.0       3           0          2
# 4     6      1847        3.0         2.0       5           0          0
#
#    STREET  MZZONE  AGE_AT_SALE  Total_price
# 0       0       3           11     22781941
# 1       2       2           22     10063653
# 2       1       3            5     13002093
# 3       1       4           28      8785897
# 4       0       5           10     17640263

# %% [markdown]
# # Correlation

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data3.corr(),annot=True,cbar=True,vmin=-1,vmax=1,square=False)
# Out:
# <Axes: >

# %% [markdown]
# # Creating linear regression model

# %%
from sklearn.preprocessing import StandardScaler as ss

# %%
data3.head(5)
# Out:
#    AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM  PARK_FACIL  BUILDTYPE  \
# 0     1      1986        2.0         1.0       5           0          0
# 1     6      1855        3.0         2.0       5           0          2
# 2     2      1220        2.0         1.0       4           0          0
# 3     2      1167        1.0         1.0       3           0          2
# 4     6      1847        3.0         2.0       5           0          0
#
#    STREET  MZZONE  AGE_AT_SALE  Total_price
# 0       0       3           11     22781941
# 1       2       2           22     10063653
# 2       1       3            5     13002093
# 3       1       4           28      8785897
# 4       0       5           10     17640263

# %%
sq_sc = ss()
tp_sc = ss()

# %%
data3.INT_SQFT = sq_sc.fit_transform(data3[['INT_SQFT']])
data3.Total_price =tp_sc.fit_transform(data3[['Total_price']])
data3.head(5)
# Out:
#    AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM  PARK_FACIL  BUILDTYPE  \
# 0     1  1.320409        2.0         1.0       5           0          0
# 1     6  1.033994        3.0         2.0       5           0          2
# 2     2 -0.354352        2.0         1.0       4           0          0
# 3     2 -0.470230        1.0         1.0       3           0          2
# 4     6  1.016503        3.0         2.0       5           0          0
#
#    STREET  MZZONE  AGE_AT_SALE  Total_price
# 0       0       3           11     2.882132
# 1       2       2           22    -0.342030
# 2       1       3            5     0.402882
# 3       1       4           28    -0.665949
# 4       0       5           10     1.578686

# %%
relation = data3[['AREA', 'INT_SQFT', 'N_BEDROOM', 'N_BATHROOM', 'N_ROOM', 'PARK_FACIL',
       'BUILDTYPE', 'STREET', 'MZZONE', 'AGE_AT_SALE', 'Total_price']].corr()
relation
# Out:
#                  AREA  INT_SQFT  N_BEDROOM  N_BATHROOM    N_ROOM  PARK_FACIL  \
# AREA         1.000000  0.351331   0.361944    0.222781  0.279363    0.010383
# INT_SQFT     0.351331  1.000000   0.786001    0.514124  0.951279    0.004618
# N_BEDROOM    0.361944  0.786001   1.000000    0.753795  0.839947   -0.009178
# N_BATHROOM   0.222781  0.514124   0.753795    1.000000  0.566998   -0.014319
# N_ROOM       0.279363  0.951279   0.839947    0.566998  1.000000   -0.000934
# PARK_FACIL   0.010383  0.004618  -0.009178   -0.014319 -0.000934    1.000000
# BUILDTYPE   -0.009517 -0.006329  -0.002261   -0.005702 -0.007127   -0.006436
# STREET       0.014482  0.008341   0.003909   -0.009326  0.000194    0.007567
# MZZONE      -0.154106  0.143226   0.049719   -0.048489  0.163697   -0.007192
# AGE_AT_SALE  0.181085 -0.012776  -0.045999   -0.021189 -0.033448   -0.009062
# Total_price -0.011230  0.620010   0.341224    0.118119  0.609345    0.146908
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = data3[['AREA', 'INT_SQFT', 'N_BEDROOM', 'N_BATHROOM', 'N_ROOM', 'PARK_FACIL',
       'BUILDTYPE', 'STREET', 'MZZONE', 'AGE_AT_SALE', 'Total_price']]          #dependent data
y = data3[['Total_price']]
x.head(5),y.head(5)
# Out:
# (   AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM  PARK_FACIL  BUILDTYPE  \
#  0     1  1.320409        2.0         1.0       5           0          0
#  1     6  1.033994        3.0         2.0       5           0          2
#  2     2 -0.354352        2.0         1.0       4           0          0
#  3     2 -0.470230        1.0         1.0       3           0          2
#  4     6  1.016503        3.0         2.0       5           0          0
#
#     STREET  MZZONE  AGE_AT_SALE  Total_price
#  0       0       3           11     2.882132
#  1       2       2           22    -0.342030
#  2       1       3            5     0.402882
#  3       1       4           28    -0.665949
#  4       0       5           10     1.578686  ,
#     Total_price
#  0     2.882132
#  1    -0.342030
#  2     0.402882
#  3    -0.665949
#  4     1.578686)

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.30, random_state=70)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((4976, 11), (2133, 11), (4976, 1), (2133, 1))

# %% [markdown]
# # Training the model

# %%
from sklearn.linear_model import LinearRegression

# %%
model_lr = LinearRegression()

# %%
model_lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model_lr.predict(X_test)

# %% [markdown]
# # Model Evaluation

# %%
model_lr.coef_*100
# Out:
# array([[ 7.79754088e-15, -1.59712482e-14,  1.10106032e-13,
#         -1.71211801e-13,  7.18622427e-15, -1.25545730e-14,
#          7.00928589e-15,  8.39496425e-15, -1.29723869e-14,
#         -6.78641683e-14,  1.00000000e+02]])

# %%
model_lr.intercept_
# Out:
# array([1.65423231e-14])

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)   #R² Score: Values closer to 1 indicate a better fit.
r2
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)   #error value
mse
# Out:
# 7.357732115503285e-29

# %%
accuracy = 1-mse   #accuracy value
accuracy
# Out:
# 1.0
